# %% [markdown]
# # Multiple Time Series Forecasting with Temporal Fusion Transformers (TFT)

# %%
! pip install -q darts
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 58.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.0/340.0 kB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.0/983.0 kB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 15.8 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.metrics import root_mean_squared_error, mean_squared_error, mean_absolute_error
from darts.timeseries import TimeSeries
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.dataprocessing.transformers import Scaler
from darts.models import RNNModel
from darts.models import TFTModel
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Time Series Analysis/Python - Time Series Forecasting/Deep Learning for Time Series Forecasting /TFT/electricity.csv',
                index_col='ds',parse_dates=True)
df.head()
# Out:
#                     unique_id      y  Exogenous1  Exogenous2
# ds
# 2016-10-22 00:00:00        BE  70.00     49593.0     57253.0
# 2016-10-22 01:00:00        BE  37.10     46073.0     51887.0
# 2016-10-22 02:00:00        BE  37.10     44927.0     51896.0
# 2016-10-22 03:00:00        BE  44.75     44483.0     48428.0
# 2016-10-22 04:00:00        BE  37.10     44338.0     46721.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8400 entries, 2016-10-22 00:00:00 to 2018-12-23 23:00:00
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unique_id   8400 non-null   object
#  1   y           8400 non-null   float64
#  2   Exogenous1  8400 non-null   float64
#  3   Exogenous2  8400 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 328.1+ KB

# %% [markdown]
# ## EDA

# %% [markdown]
# Look at electricity pricing plots for each country.

# %%
for country in df.unique_id.unique():
  plt.figure(figsize=(10,5))
  df[df['unique_id']==country].y.plot(title=f'{country} Electricity Price', color='teal')
  plt.ylabel('Price')
  plt.show()

# %% [markdown]
# Subset df for only Belgium and France $[BE,FR]$

# %%
country_list = ['BE','FR']

# %%
df = df[df['unique_id'].isin(country_list)]
df.head()
# Out:
#                     unique_id      y  Exogenous1  Exogenous2
# ds
# 2016-10-22 00:00:00        BE  70.00     49593.0     57253.0
# 2016-10-22 01:00:00        BE  37.10     46073.0     51887.0
# 2016-10-22 02:00:00        BE  37.10     44927.0     51896.0
# 2016-10-22 03:00:00        BE  44.75     44483.0     48428.0
# 2016-10-22 04:00:00        BE  37.10     44338.0     46721.0

# %% [markdown]
# Get plots of electricity prices on same plot.

# %%
# Group by 'unique_id' and plot each group

plt.figure(figsize=(12, 6))
for uid, group in df.groupby('unique_id'):
    plt.plot(group.index, group['y'], label=str(uid))

plt.xlabel('Time')
plt.ylabel('Electricity Price')
plt.title('Electricity Price vs. Time')
plt.legend(frameon=True)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Create a dictionary to store dataframes for each country
country_dfs = {}

for country in country_list:
  country_dfs[f"df_{country}"] = df[df['unique_id']==country].copy() # Added .copy() to avoid SettingWithCopyWarning

# We can access the dataframes like this:
df_BE = country_dfs['df_BE']
df_FR = country_dfs['df_FR']

# %%
# Seasonal Decomposition Function

def seasonal_decomposition(series,model,period):
  result = seasonal_decompose(series, model=model, period=period)
  fig = result.plot()
  fig.set_figheight(8)
  fig.set_figwidth(12)
  plt.show()
  return

# %%
seasonal_decomposition(df_BE['y'],model='additive',period=24)

# %%
seasonal_decomposition(df_FR['y'],model='additive',period=24)

# %% [markdown]
# ## ACF and PACF

# %%
# Plot the ACF for the electricity pricing data

def plot_acf_pacf(series, lags, color, plot_variable):

  fig, ax = plt.subplots(figsize=(15,7))
  plot_acf(series, lags=lags, ax=ax, color=color)
  plt.title(f"ACF of {plot_variable}")
  plt.show()

  fig, ax = plt.subplots(figsize=(15,7))
  plot_pacf(series, lags=lags, ax=ax, color=color)
  plt.title(f"PACF of {plot_variable}")
  plt.show()
  return

# %%
plot_acf_pacf(df_BE['y'], lags=100, color='teal', plot_variable='BE Electricity Price')

# %%
plot_acf_pacf(df_FR['y'], lags=100, color='blue', plot_variable='FR Electricity Price')

# %% [markdown]
# ## Stationarity

# %%
def adf_test(series, title=None):

  # Run the ADF test
  result = adfuller(series.dropna(), autolag='AIC')

  # Extract and print results
  print('ADF Statistic:', result[0])
  print('p-value:', result[1])
  print('Critical Values:')
  for key, value in result[4].items():
      print(f'   {key}: {value}')

  # Interpretation
  if result[1] < 0.05:
      print("Result: The series is likely stationary (reject H0).")
  else:
      print("Result: The series is likely non-stationary (fail to reject H0).")

# %%
adf_test(df_BE['y'])
# Out:
# ADF Statistic: -3.5000159242857722
# p-value: 0.007986685101526971
# Critical Values:
#    1%: -3.4343097809950986
#    5%: -2.8632890172254655
#    10%: -2.5677011356149544
# Result: The series is likely stationary (reject H0).

# %%
adf_test(df_FR['y'])
# Out:
# ADF Statistic: -3.6026637156827896
# p-value: 0.005710306945452253
# Critical Values:
#    1%: -3.4343097809950986
#    5%: -2.8632890172254655
#    10%: -2.5677011356149544
# Result: The series is likely stationary (reject H0).

# %% [markdown]
# Code the `unique_id` column of the original $[BE, FR]$ dataframe and make `ds` a column.

# %%
df['unique_id'] = df['unique_id'].astype('category')
df['unique_id'] = df['unique_id'].cat.codes
df = df.reset_index()
df.head()
# Out:
#                    ds  unique_id      y  Exogenous1  Exogenous2
# 0 2016-10-22 00:00:00          0  70.00     49593.0     57253.0
# 1 2016-10-22 01:00:00          0  37.10     46073.0     51887.0
# 2 2016-10-22 02:00:00          0  37.10     44927.0     51896.0
# 3 2016-10-22 03:00:00          0  44.75     44483.0     48428.0
# 4 2016-10-22 04:00:00          0  37.10     44338.0     46721.0

# %%
# Set up the variables for the time series
TIME_COL = "ds"
TARGET = "y"
GROUP_COL = ["unique_id"]
FREQ = "h" # hourly data

# %%
# Create the time series instance from the DataFrame using group-based columns
series = TimeSeries.from_group_dataframe(
    df=df,                # DataFrame containing the data
    time_col=TIME_COL,    # Column representing the time dimension
    group_cols=GROUP_COL, # Column(s) representing the group or series identifier(s)
    value_cols=TARGET,    # Column representing the target variable (the value to forecast)
    freq=FREQ             # Frequency of the data
)

# Display the time series instance
series
# Out:
# [<TimeSeries (ds: 1680, component: 1, sample: 1)> Size: 13kB
#  array([[[70.  ]],
#
#         [[37.1 ]],
#
#         [[37.1 ]],
#
#         ...,
#
#         [[52.18]],
#
#         [[54.38]],
#
#         [[50.78]]])
#  Coordinates:
#    * ds         (ds) datetime64[ns] 13kB 2016-10-22 ... 2016-12-30T23:00:00
#    * component  (component) object 8B 'y'
#  Dimensions without coordinates: sample
#  Attributes:
#      static_covariates:  static_covariates  unique_id\ny                      ...
#      hierarchy:          None
#      metadata:           None,
#  <TimeSeries (ds: 1680, component: 1, sample: 1)> Size: 13kB
#  array([[[54.7 ]],
#
#         [[51.16]],
#
#         [[48.86]],
#
#         ...,
#
#         [[69.59]],
#
#         [[69.09]],
#
#         [[66.7 ]]])
#  Coordinates:
#    * ds         (ds) datetime64[ns] 13kB 2016-10-22 ... 2016-12-30T23:00:00
#    * component  (component) object 8B 'y'
#  Dimensions without coordinates: sample
#  Attributes:
#      static_covariates:  static_covariates  unique_id\ny                      ...
#      hierarchy:          None
#      metadata:           None]

# %% [markdown]
# ## Create Past Covariates

# %%
# Define the df columns that will be used as past covariates
COVARIATES = ["Exogenous1", "Exogenous2"]

# %%
# Create the past covariates time series instance from the DataFrame using group-based columns

past_covariates = TimeSeries.from_group_dataframe(
    df=df,                # DataFrame containing the data
    time_col=TIME_COL,    # Column representing the time dimension
    group_cols=GROUP_COL, # Column(s) representing the group or series identifier(s)
    value_cols=COVARIATES, # Columns representing the exogenous variables (past covariates)
    freq=FREQ             # Frequency of the data
)

# Display the past covariates time series instance
past_covariates
# Out:
# [<TimeSeries (ds: 1680, component: 2, sample: 1)> Size: 27kB
#  array([[[49593.],
#          [57253.]],
#
#         [[46073.],
#          [51887.]],
#
#         [[44927.],
#          [51896.]],
#
#         ...,
#
#         [[66647.],
#          [71003.]],
#
#         [[65886.],
#          [68330.]],
#
#         [[66846.],
#          [72259.]]])
#  Coordinates:
#    * ds         (ds) datetime64[ns] 13kB 2016-10-22 ... 2016-12-30T23:00:00
#    * component  (component) object 16B 'Exogenous1' 'Exogenous2'
#  Dimensions without coordinates: sample
#  Attributes:
#      static_covariates:  static_covariates  unique_id\nglobal_components      ...
#      hierarchy:          None
#      metadata:           None,
#  <TimeSeries (ds: 1680, component: 2, sample: 1)> Size: 27kB
#  array([[[49593.],
#          [57253.]],
#
#         [[46073.],
#          [51887.]],
#
#         [[44927.],
#          [51896.]],
#
#         ...,
#
#         [[66647.],
#          [71003.]],
#
#         [[65886.],
#          [68330.]],
#
#         [[66846.],
#          [72259.]]])
#  Coordinates:
#    * ds         (ds) datetime64[ns] 13kB 2016-10-22 ... 2016-12-30T23:00:00
#    * component  (component) object 16B 'Exogenous1' 'Exogenous2'
#  Dimensions without coordinates: sample
#  Attributes:
#      static_covariates:  static_covariates  unique_id\nglobal_components      ...
#      hierarchy:          None
#      metadata:           None]

# %% [markdown]
# ## Create Future Covariates

# %%
# Read in the future dataset

df_future = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Time Series Analysis/Python - Time Series Forecasting/Deep Learning for Time Series Forecasting /TFT/electricity-future.csv',
                index_col='ds',parse_dates=True)
df_future.head()
# Out:
#                     unique_id  Exogenous1  Exogenous2
# ds
# 2016-12-31 00:00:00        BE     64108.0     70318.0
# 2016-12-31 01:00:00        BE     62492.0     67898.0
# 2016-12-31 02:00:00        BE     61571.0     68379.0
# 2016-12-31 03:00:00        BE     60381.0     64972.0
# 2016-12-31 04:00:00        BE     60298.0     62900.0

# %%
df_future.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2016-12-31 00:00:00 to 2018-12-24 23:00:00
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unique_id   120 non-null    object
#  1   Exogenous1  120 non-null    float64
#  2   Exogenous2  120 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.8+ KB

# %%
df_future = df_future[df_future['unique_id'].isin(country_list)]
df_future.head()
# Out:
#                     unique_id  Exogenous1  Exogenous2
# ds
# 2016-12-31 00:00:00        BE     64108.0     70318.0
# 2016-12-31 01:00:00        BE     62492.0     67898.0
# 2016-12-31 02:00:00        BE     61571.0     68379.0
# 2016-12-31 03:00:00        BE     60381.0     64972.0
# 2016-12-31 04:00:00        BE     60298.0     62900.0

# %%
df_future['unique_id'] = df_future['unique_id'].astype('category')
df_future['unique_id'] = df_future['unique_id'].cat.codes
df_future = df_future.reset_index()
df_future.head()
# Out:
#                    ds  unique_id  Exogenous1  Exogenous2
# 0 2016-12-31 00:00:00          0     64108.0     70318.0
# 1 2016-12-31 01:00:00          0     62492.0     67898.0
# 2 2016-12-31 02:00:00          0     61571.0     68379.0
# 3 2016-12-31 03:00:00          0     60381.0     64972.0
# 4 2016-12-31 04:00:00          0     60298.0     62900.0

# %%
# Create past_df with just covariates

past_df = df.drop(columns=['y'])
past_df.head()
# Out:
#                    ds  unique_id  Exogenous1  Exogenous2
# 0 2016-10-22 00:00:00          0     49593.0     57253.0
# 1 2016-10-22 01:00:00          0     46073.0     51887.0
# 2 2016-10-22 02:00:00          0     44927.0     51896.0
# 3 2016-10-22 03:00:00          0     44483.0     48428.0
# 4 2016-10-22 04:00:00          0     44338.0     46721.0

# %%
# Concatenate past_df with future_df

df_full = pd.concat([past_df, df_future])
df_full.head()
# Out:
#                    ds  unique_id  Exogenous1  Exogenous2
# 0 2016-10-22 00:00:00          0     49593.0     57253.0
# 1 2016-10-22 01:00:00          0     46073.0     51887.0
# 2 2016-10-22 02:00:00          0     44927.0     51896.0
# 3 2016-10-22 03:00:00          0     44483.0     48428.0
# 4 2016-10-22 04:00:00          0     44338.0     46721.0

# %%
df_full.tail()
# Out:
#                     ds  unique_id  Exogenous1  Exogenous2
# 43 2016-12-31 19:00:00          1     70329.0     73957.0
# 44 2016-12-31 20:00:00          1     69121.0     72544.0
# 45 2016-12-31 21:00:00          1     66647.0     69451.0
# 46 2016-12-31 22:00:00          1     65886.0     67823.0
# 47 2016-12-31 23:00:00          1     66846.0     72876.0

# %%
# Create the future covariates time series instance from the full DataFrame using group-based columns

future_covariates = TimeSeries.from_group_dataframe(
    df=df_full,           # Full DataFrame containing both current and future data
    time_col=TIME_COL,    # Column representing the time dimension
    group_cols=GROUP_COL, # Column(s) representing the group or series identifier(s)
    value_cols=COVARIATES, # Columns representing the exogenous variables (future covariates)
    freq=FREQ             # Frequency of the data
)

# Display the future covariates time series instance
future_covariates
# Out:
# [<TimeSeries (ds: 1704, component: 2, sample: 1)> Size: 27kB
#  array([[[49593.],
#          [57253.]],
#
#         [[46073.],
#          [51887.]],
#
#         [[44927.],
#          [51896.]],
#
#         ...,
#
#         [[66647.],
#          [69451.]],
#
#         [[65886.],
#          [67823.]],
#
#         [[66846.],
#          [72876.]]])
#  Coordinates:
#    * ds         (ds) datetime64[ns] 14kB 2016-10-22 ... 2016-12-31T23:00:00
#    * component  (component) object 16B 'Exogenous1' 'Exogenous2'
#  Dimensions without coordinates: sample
#  Attributes:
#      static_covariates:  static_covariates  unique_id\nglobal_components      ...
#      hierarchy:          None
#      metadata:           None,
#  <TimeSeries (ds: 1704, component: 2, sample: 1)> Size: 27kB
#  array([[[49593.],
#          [57253.]],
#
#         [[46073.],
#          [51887.]],
#
#         [[44927.],
#          [51896.]],
#
#         ...,
#
#         [[66647.],
#          [69451.]],
#
#         [[65886.],
#          [67823.]],
#
#         [[66846.],
#          [72876.]]])
#  Coordinates:
#    * ds         (ds) datetime64[ns] 14kB 2016-10-22 ... 2016-12-31T23:00:00
#    * component  (component) object 16B 'Exogenous1' 'Exogenous2'
#  Dimensions without coordinates: sample
#  Attributes:
#      static_covariates:  static_covariates  unique_id\nglobal_components      ...
#      hierarchy:          None
#      metadata:           None]

# %% [markdown]
# ## Scaling

# %%
# Two scalers: one for the series, one for the covariates

scaler1 = Scaler()
scaler2 = Scaler()

# %%
y_transformed = scaler1.fit_transform(series)
past_covariates_transformed = scaler2.fit_transform(past_covariates)
future_covariates_transformed = scaler2.transform(future_covariates)

# %% [markdown]
# ## TFT Model Parameters
#
# * `input_chunk_length`: 96 hours
# * `output_chunk_length` or `forecast_horizon`: 24 hours
# * `hidden_size`: 16
# * `LSTM_layers`: 2
# * `num_attention_heads`: 4
# * `dropout_rate`: 0.1
# * `batch_size`: 64
# * `n_epochs`: 10
# * `use_static_covariates`=`True`

# %%
# Set forecast horizon

forecast_horizon = 24

# %%
# Build and fit the TFT model

tft = TFTModel(input_chunk_length=96,
               output_chunk_length=forecast_horizon,
               hidden_size=16,
               lstm_layers=2,
               num_attention_heads=4,
               dropout=0.1,
               batch_size=64,
               n_epochs=10,
               use_static_covariates=True,
               pl_trainer_kwargs={'accelerator': 'gpu', 'devices': [0]},
               random_state=42,
               )

tft.fit(y_transformed,
        past_covariates=past_covariates_transformed,
        future_covariates=future_covariates_transformed,
        )
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA L4') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ## Cross Validation

# %%
cv = tft.historical_forecasts(
    series=y_transformed,
    past_covariates=past_covariates_transformed,
    future_covariates=future_covariates_transformed,
    forecast_horizon=forecast_horizon,
    start=int((len(df)/2) - (10*forecast_horizon)), # Cast start to an integer
    stride=forecast_horizon,
    retrain=True,
    last_points_only=False
    )
# Out:
# WARNING:darts.utils.historical_forecasts.utils:`enable_optimization=True` is ignored because `retrain` is not `False` or `0`. To hide this warning, set `show_warnings=False` or `enable_optimization=False`.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 3.0 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 1.2 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.4 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.4 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 676    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 23.1 K    Trainable params
# 0         Non-trainable params
# 23.1 K    Total params
# 0.092     Total estimated model params size (MB)
# 261       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
cv
# Out:
# [[<TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.29545528]],
#
#          [[0.08628592]],
#
#          [[0.02470228]],
#
#          [[0.05421515]],
#
#          [[0.05954349]],
#
#          [[0.12166178]],
#
#          [[0.03750493]],
#
#          [[0.08687254]],
#
#          [[0.05076646]],
#
#          [[0.09112797]],
#
#   ...
#
#          [[0.08994802]],
#
#          [[0.06431401]],
#
#          [[0.09301753]],
#
#          [[0.10389227]],
#
#          [[0.06868542]],
#
#          [[0.09735768]],
#
#          [[0.05201355]],
#
#          [[0.29614329]],
#
#          [[0.3033746 ]],
#
#          [[0.07924762]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-21 ... 2016-12-21T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.28964665]],
#
#          [[0.0843948 ]],
#
#          [[0.0343162 ]],
#
#          [[0.05943649]],
#
#          [[0.06197172]],
#
#          [[0.12479176]],
#
#          [[0.04463652]],
#
#          [[0.09324379]],
#
#          [[0.05786812]],
#
#          [[0.09592793]],
#
#   ...
#
#          [[0.09615305]],
#
#          [[0.07176554]],
#
#          [[0.10060143]],
#
#          [[0.11187701]],
#
#          [[0.07570508]],
#
#          [[0.09796904]],
#
#          [[0.06613345]],
#
#          [[0.29061444]],
#
#          [[0.29777418]],
#
#          [[0.08024265]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-22 ... 2016-12-22T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.28958969]],
#
#          [[0.08851029]],
#
#          [[0.03022668]],
#
#          [[0.0502734 ]],
#
#          [[0.05955761]],
#
#          [[0.12613156]],
#
#          [[0.04380105]],
#
#          [[0.09229627]],
#
#          [[0.05969286]],
#
#          [[0.09465649]],
#
#   ...
#
#          [[0.09046232]],
#
#          [[0.06368075]],
#
#          [[0.0928967 ]],
#
#          [[0.10999085]],
#
#          [[0.06732778]],
#
#          [[0.10645516]],
#
#          [[0.04872273]],
#
#          [[0.28379256]],
#
#          [[0.29130237]],
#
#          [[0.07656433]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-23 ... 2016-12-23T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.2784906 ]],
#
#          [[0.08523289]],
#
#          [[0.02676343]],
#
#          [[0.04480602]],
#
#          [[0.04948849]],
#
#          [[0.13787089]],
#
#          [[0.03254696]],
#
#          [[0.07720668]],
#
#          [[0.04161667]],
#
#          [[0.07824849]],
#
#   ...
#
#          [[0.08418048]],
#
#          [[0.0558214 ]],
#
#          [[0.09085465]],
#
#          [[0.11168343]],
#
#          [[0.05888987]],
#
#          [[0.12072135]],
#
#          [[0.04202849]],
#
#          [[0.27363741]],
#
#          [[0.28205767]],
#
#          [[0.06984283]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-24 ... 2016-12-24T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.27759811]],
#
#          [[0.07547715]],
#
#          [[0.02475532]],
#
#          [[0.03958761]],
#
#          [[0.0492835 ]],
#
#          [[0.14603483]],
#
#          [[0.03151756]],
#
#          [[0.06349654]],
#
#          [[0.03291551]],
#
#          [[0.06056386]],
#
#   ...
#
#          [[0.06849423]],
#
#          [[0.04256374]],
#
#          [[0.07250746]],
#
#          [[0.11851882]],
#
#          [[0.04650166]],
#
#          [[0.13098532]],
#
#          [[0.04338972]],
#
#          [[0.27057593]],
#
#          [[0.27937657]],
#
#          [[0.07182036]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-25 ... 2016-12-25T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.26769816]],
#
#          [[0.07789084]],
#
#          [[0.0230074 ]],
#
#          [[0.02856345]],
#
#          [[0.03608556]],
#
#          [[0.14631499]],
#
#          [[0.02860802]],
#
#          [[0.07073457]],
#
#          [[0.03707893]],
#
#          [[0.07149478]],
#
#   ...
#
#          [[0.08052004]],
#
#          [[0.05062039]],
#
#          [[0.08487778]],
#
#          [[0.1108753 ]],
#
#          [[0.05610708]],
#
#          [[0.11548786]],
#
#          [[0.04007717]],
#
#          [[0.26754046]],
#
#          [[0.2748317 ]],
#
#          [[0.07380462]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-26 ... 2016-12-26T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.26781259]],
#
#          [[0.07750691]],
#
#          [[0.02430062]],
#
#          [[0.04158084]],
#
#          [[0.04891202]],
#
#          [[0.13626332]],
#
#          [[0.03386825]],
#
#          [[0.07599819]],
#
#          [[0.04527711]],
#
#          [[0.07753949]],
#
#   ...
#
#          [[0.08085046]],
#
#          [[0.05352866]],
#
#          [[0.0843627 ]],
#
#          [[0.11449016]],
#
#          [[0.06068388]],
#
#          [[0.10963085]],
#
#          [[0.04706057]],
#
#          [[0.26545642]],
#
#          [[0.27256179]],
#
#          [[0.07136111]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-27 ... 2016-12-27T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.26379023]],
#
#          [[0.08552647]],
#
#          [[0.02876011]],
#
#          [[0.05061504]],
#
#          [[0.04657556]],
#
#          [[0.1243653 ]],
#
#          [[0.03383313]],
#
#          [[0.07837062]],
#
#          [[0.04501219]],
#
#          [[0.08019784]],
#
#   ...
#
#          [[0.08192809]],
#
#          [[0.05764473]],
#
#          [[0.08682452]],
#
#          [[0.10627308]],
#
#          [[0.06260412]],
#
#          [[0.1059053 ]],
#
#          [[0.04858305]],
#
#          [[0.25936308]],
#
#          [[0.26550383]],
#
#          [[0.06565335]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-28 ... 2016-12-28T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.25597213]],
#
#          [[0.08278963]],
#
#          [[0.02692369]],
#
#          [[0.04410867]],
#
#          [[0.05256892]],
#
#          [[0.12666987]],
#
#          [[0.03913856]],
#
#          [[0.08103491]],
#
#          [[0.04873178]],
#
#          [[0.08334183]],
#
#   ...
#
#          [[0.08467291]],
#
#          [[0.05798641]],
#
#          [[0.08813931]],
#
#          [[0.10704524]],
#
#          [[0.06539926]],
#
#          [[0.10130543]],
#
#          [[0.05271224]],
#
#          [[0.25906627]],
#
#          [[0.26498438]],
#
#          [[0.07780643]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-29 ... 2016-12-29T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.25696157]],
#
#          [[0.08427928]],
#
#          [[0.0270912 ]],
#
#          [[0.05383125]],
#
#          [[0.05022135]],
#
#          [[0.11802362]],
#
#          [[0.03957583]],
#
#          [[0.07750417]],
#
#          [[0.04952401]],
#
#          [[0.0807366 ]],
#
#   ...
#
#          [[0.07939295]],
#
#          [[0.06111122]],
#
#          [[0.08065835]],
#
#          [[0.10308704]],
#
#          [[0.06532238]],
#
#          [[0.09720322]],
#
#          [[0.05012691]],
#
#          [[0.25859248]],
#
#          [[0.26382641]],
#
#          [[0.0706447 ]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-30 ... 2016-12-30T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None],
#  [<TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.24864103]],
#
#          [[0.08386451]],
#
#          [[0.01726486]],
#
#          [[0.0399525 ]],
#
#          [[0.03580781]],
#
#          [[0.08603043]],
#
#          [[0.04071872]],
#
#          [[0.07042992]],
#
#          [[0.05430616]],
#
#          [[0.07680877]],
#
#   ...
#
#          [[0.07545328]],
#
#          [[0.0585905 ]],
#
#          [[0.07264342]],
#
#          [[0.09038084]],
#
#          [[0.05568728]],
#
#          [[0.08505498]],
#
#          [[0.05193962]],
#
#          [[0.24567056]],
#
#          [[0.24888177]],
#
#          [[0.06697134]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-21 ... 2016-12-21T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.23562663]],
#
#          [[0.08030538]],
#
#          [[0.02122123]],
#
#          [[0.03879499]],
#
#          [[0.02532858]],
#
#          [[0.08660944]],
#
#          [[0.03798771]],
#
#          [[0.0675111 ]],
#
#          [[0.05211511]],
#
#          [[0.07087272]],
#
#   ...
#
#          [[0.07200728]],
#
#          [[0.06068755]],
#
#          [[0.07176285]],
#
#          [[0.0875643 ]],
#
#          [[0.05194067]],
#
#          [[0.08444596]],
#
#          [[0.04769428]],
#
#          [[0.22856748]],
#
#          [[0.23173294]],
#
#          [[0.05314505]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-22 ... 2016-12-22T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.22092236]],
#
#          [[0.06912319]],
#
#          [[0.02496301]],
#
#          [[0.0348923 ]],
#
#          [[0.02313591]],
#
#          [[0.08294551]],
#
#          [[0.03300469]],
#
#          [[0.06144148]],
#
#          [[0.04840433]],
#
#          [[0.06482003]],
#
#   ...
#
#          [[0.06502112]],
#
#          [[0.05117905]],
#
#          [[0.0638486 ]],
#
#          [[0.0815825 ]],
#
#          [[0.04795648]],
#
#          [[0.08246129]],
#
#          [[0.04248161]],
#
#          [[0.21265696]],
#
#          [[0.21660779]],
#
#          [[0.0471305 ]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-23 ... 2016-12-23T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.21146525]],
#
#          [[0.06095926]],
#
#          [[0.02449586]],
#
#          [[0.02772761]],
#
#          [[0.01537395]],
#
#          [[0.08641608]],
#
#          [[0.02391522]],
#
#          [[0.04596393]],
#
#          [[0.03170369]],
#
#          [[0.0468074 ]],
#
#   ...
#
#          [[0.0547164 ]],
#
#          [[0.04491901]],
#
#          [[0.05544996]],
#
#          [[0.07852505]],
#
#          [[0.03864295]],
#
#          [[0.08534972]],
#
#          [[0.02811245]],
#
#          [[0.19969347]],
#
#          [[0.20655947]],
#
#          [[0.0384678 ]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-24 ... 2016-12-24T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.20413104]],
#
#          [[0.0599623 ]],
#
#          [[0.02281131]],
#
#          [[0.03062219]],
#
#          [[0.01534568]],
#
#          [[0.0804135 ]],
#
#          [[0.01881023]],
#
#          [[0.03513454]],
#
#          [[0.02068513]],
#
#          [[0.03358986]],
#
#   ...
#
#          [[0.04191849]],
#
#          [[0.03703038]],
#
#          [[0.04238931]],
#
#          [[0.06760021]],
#
#          [[0.03011754]],
#
#          [[0.07849184]],
#
#          [[0.02693194]],
#
#          [[0.1862131 ]],
#
#          [[0.19286007]],
#
#          [[0.03672895]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-25 ... 2016-12-25T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.19718341]],
#
#          [[0.04687034]],
#
#          [[0.01954454]],
#
#          [[0.02345914]],
#
#          [[0.02035867]],
#
#          [[0.07619877]],
#
#          [[0.01819037]],
#
#          [[0.04641135]],
#
#          [[0.02683321]],
#
#          [[0.04728871]],
#
#   ...
#
#          [[0.05697741]],
#
#          [[0.04636992]],
#
#          [[0.05920234]],
#
#          [[0.07376485]],
#
#          [[0.04195504]],
#
#          [[0.07887647]],
#
#          [[0.03976552]],
#
#          [[0.19954067]],
#
#          [[0.20357331]],
#
#          [[0.04866037]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-26 ... 2016-12-26T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.20453424]],
#
#          [[0.05502541]],
#
#          [[0.02103323]],
#
#          [[0.03347701]],
#
#          [[0.02533588]],
#
#          [[0.07705193]],
#
#          [[0.02347492]],
#
#          [[0.05574802]],
#
#          [[0.03774783]],
#
#          [[0.06134777]],
#
#   ...
#
#          [[0.06200633]],
#
#          [[0.04715174]],
#
#          [[0.06069956]],
#
#          [[0.08049511]],
#
#          [[0.04891936]],
#
#          [[0.08832435]],
#
#          [[0.04578418]],
#
#          [[0.20923492]],
#
#          [[0.21310236]],
#
#          [[0.05636256]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-27 ... 2016-12-27T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.20546031]],
#
#          [[0.06270094]],
#
#          [[0.02250121]],
#
#          [[0.03726731]],
#
#          [[0.03461647]],
#
#          [[0.07350641]],
#
#          [[0.03152286]],
#
#          [[0.06065678]],
#
#          [[0.04494393]],
#
#          [[0.06580473]],
#
#   ...
#
#          [[0.06332466]],
#
#          [[0.04691078]],
#
#          [[0.06022419]],
#
#          [[0.07618614]],
#
#          [[0.05105895]],
#
#          [[0.08554418]],
#
#          [[0.05096802]],
#
#          [[0.20826995]],
#
#          [[0.21142692]],
#
#          [[0.06427132]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-28 ... 2016-12-28T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.19133934]],
#
#          [[0.06755478]],
#
#          [[0.02394176]],
#
#          [[0.0381895 ]],
#
#          [[0.0335905 ]],
#
#          [[0.07969075]],
#
#          [[0.03812448]],
#
#          [[0.0633464 ]],
#
#          [[0.05090452]],
#
#          [[0.06908283]],
#
#   ...
#
#          [[0.06563276]],
#
#          [[0.05190745]],
#
#          [[0.06413331]],
#
#          [[0.08187708]],
#
#          [[0.05570144]],
#
#          [[0.08917349]],
#
#          [[0.05456281]],
#
#          [[0.20801208]],
#
#          [[0.21009271]],
#
#          [[0.06544584]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-29 ... 2016-12-29T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None,
#   <TimeSeries (ds: 24, component: 1, sample: 1)> Size: 192B
#   array([[[0.20586324]],
#
#          [[0.07841106]],
#
#          [[0.02536288]],
#
#          [[0.03593108]],
#
#          [[0.01653977]],
#
#          [[0.07403195]],
#
#          [[0.03439223]],
#
#          [[0.058127  ]],
#
#          [[0.04651626]],
#
#          [[0.06153533]],
#
#   ...
#
#          [[0.06372264]],
#
#          [[0.05174852]],
#
#          [[0.06226841]],
#
#          [[0.08035332]],
#
#          [[0.04968378]],
#
#          [[0.08306284]],
#
#          [[0.04571033]],
#
#          [[0.20886317]],
#
#          [[0.20971733]],
#
#          [[0.04913535]]])
#   Coordinates:
#     * ds         (ds) datetime64[ns] 192B 2016-12-30 ... 2016-12-30T23:00:00
#     * component  (component) object 8B 'y'
#   Dimensions without coordinates: sample
#   Attributes:
#       static_covariates:  static_covariates  unique_id\ny                      ...
#       hierarchy:          None
#       metadata:           None]]

# %%
len(df)/2
# Out:
# 1680.0

# %%
# Number of time series generated in the cross-validation
print(len(cv))
# Number of backtests or forecasting windows in the first time series
print(len(cv[0]))
# Number of forecasted points in the first backtest of the first time series
print(len(cv[0][0]))

number_backtests = len(cv[0])
number_series = len(cv)
# Out:
# 2
# 10
# 24

# %% [markdown]
# ## Calculate cross-validation error

# %%
rmse_cv = []

# Loop through each backtesting period
for j in range(number_backtests):
  period_predictions = []

  # Collect the predictions
  for i in range(number_series):
    period_predictions.append(cv[i][j])

  # Unscale the preditions
  period_predictions_unscaled = scaler1.inverse_transform(period_predictions)

  # Calculate the RMSE for the current period for each series
  series_rmse = []
  for i in range(number_series):
    predictions = period_predictions_unscaled[i]
    predictions_df = predictions.to_dataframe()

    # Get the index for the predictions
    start = predictions_df.index.min()
    end = predictions_df.index.max()

    # Extract actual values for the time range and specific series
    actuals = df[(df['ds'] >= start) & (df['ds'] <= end) & (df['unique_id'] == i)]
    actuals = actuals.set_index('ds')['y']

    # Ensure that the index predictions match
    # print(predictions_df.index == actuals.index)

    # Calculate the RMSE
    error_cv = np.sqrt(mean_squared_error(actuals, predictions_df['y']))
    series_rmse.append(error_cv)

  # Append the mean rmse for the current period
  rmse_cv.append(np.mean(series_rmse))

# Calculate and print the overall RMSE across all periods and series
print(f"RMSE: {np.mean(rmse_cv)}")
# Out:
# RMSE: 55.57207391887755

# %% [markdown]
# ## Parameter Tuning

# %% [markdown]
# We will perform `ParameterSampler` tuning

# %%
from sklearn.model_selection import ParameterSampler

# Parameter Grid

param_grid = {
    'input_chunk_length': [48,96, 172],
    'output_chunk_length': [24],
    'hidden_size': [8, 16, 24],
    'num_attention_heads': [2,4,6],
    'dropout': [0.1, 0.2, 0.3],
    'batch_size': [32, 64, 128],
    'lstm_layers': [1,2,4],
    'n_epochs': [5,10,20]
}

# Number of parameter combinations to try
n_iter=10

# Generate a list of parameter combinations to sample from the parameter grid
param_list = list(ParameterSampler(param_grid, n_iter=n_iter, random_state=42))

# Duplicate the parameter list for further use or comparison
param_list2 = param_list

# Print the list of parameter combinations
print(param_list)
# Out:
# [{'output_chunk_length': 24, 'num_attention_heads': 6, 'n_epochs': 10, 'lstm_layers': 4, 'input_chunk_length': 96, 'hidden_size': 16, 'dropout': 0.1, 'batch_size': 64}, {'output_chunk_length': 24, 'num_attention_heads': 4, 'n_epochs': 20, 'lstm_layers': 4, 'input_chunk_length': 172, 'hidden_size': 8, 'dropout': 0.3, 'batch_size': 64}, {'output_chunk_length': 24, 'num_attention_heads': 6, 'n_epochs': 10, 'lstm_layers': 4, 'input_chunk_length': 172, 'hidden_size': 16, 'dropout': 0.2, 'batch_size': 64}, {'output_chunk_length': 24, 'num_attention_heads': 2, 'n_epochs': 20, 'lstm_layers': 2, 'input_chunk_length': 96, 'hidden_size': 16, 'dropout': 0.2, 'batch_size': 64}, {'output_chunk_length': 24, 'num_attention_heads': 2, 'n_epochs': 5, 'lstm_layers': 4, 'input_chunk_length': 48, 'hidden_size': 24, 'dropout': 0.1, 'batch_size': 128}, {'output_chunk_length': 24, 'num_attention_heads': 2, 'n_epochs': 5, 'lstm_layers': 2, 'input_chunk_length': 172, 'hidden_size': 24, 'dropout': 0.3, 'batch_size': 128}, {'output_chunk_length': 24, 'num_attention_heads': 4, 'n_epochs': 20, 'lstm_layers': 1, 'input_chunk_length': 172, 'hidden_size': 24, 'dropout': 0.2, 'batch_size': 32}, {'output_chunk_length': 24, 'num_attention_heads': 6, 'n_epochs': 10, 'lstm_layers': 4, 'input_chunk_length': 48, 'hidden_size': 8, 'dropout': 0.3, 'batch_size': 64}, {'output_chunk_length': 24, 'num_attention_heads': 2, 'n_epochs': 20, 'lstm_layers': 1, 'input_chunk_length': 48, 'hidden_size': 16, 'dropout': 0.2, 'batch_size': 32}, {'output_chunk_length': 24, 'num_attention_heads': 2, 'n_epochs': 20, 'lstm_layers': 4, 'input_chunk_length': 48, 'hidden_size': 8, 'dropout': 0.1, 'batch_size': 128}]

# %%
# Time as an Encoder - the idea is to convert 'Year' to a small value for further processing

def encode_year(idx):
  return (idx.year-2000)/50  # 2000 and 50 are arbitrarily-chosen numbers

# %%
# Set up the 'add_encoders' dictionary

add_encoders = {
    'cyclic': {'future': ['hour','day','dayofweek','week','month']},
    'datetime_attribute': {'future': ['hour','day','dayofweek','week','month']},
    'position': {'past': ['relative'], 'future': ['relative']},
    'custom' : {'past': [encode_year], 'future': [encode_year]},
    'transformer': Scaler(),
    'tz': 'CET'
    }

# %%
# Define fixed parameters that will be used across all configurations

fixed_params = {
    'use_static_covariates': True,
    'add_encoders': add_encoders,
    'pl_trainer_kwargs': {'accelerator': 'gpu', "devices": [0]},
    }

# Update each parameter set in the list with the fixed parameters using the '.update()' function
for params in param_list:
  params.update(fixed_params)

# %%
# Check the params list
param_list
# Out:
# [{'output_chunk_length': 24,
#   'num_attention_heads': 6,
#   'n_epochs': 10,
#   'lstm_layers': 4,
#   'input_chunk_length': 96,
#   'hidden_size': 16,
#   'dropout': 0.1,
#   'batch_size': 64,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 4,
#   'n_epochs': 20,
#   'lstm_layers': 4,
#   'input_chunk_length': 172,
#   'hidden_size': 8,
#   'dropout': 0.3,
#   'batch_size': 64,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 6,
#   'n_epochs': 10,
#   'lstm_layers': 4,
#   'input_chunk_length': 172,
#   'hidden_size': 16,
#   'dropout': 0.2,
#   'batch_size': 64,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 2,
#   'n_epochs': 20,
#   'lstm_layers': 2,
#   'input_chunk_length': 96,
#   'hidden_size': 16,
#   'dropout': 0.2,
#   'batch_size': 64,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 2,
#   'n_epochs': 5,
#   'lstm_layers': 4,
#   'input_chunk_length': 48,
#   'hidden_size': 24,
#   'dropout': 0.1,
#   'batch_size': 128,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 2,
#   'n_epochs': 5,
#   'lstm_layers': 2,
#   'input_chunk_length': 172,
#   'hidden_size': 24,
#   'dropout': 0.3,
#   'batch_size': 128,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 4,
#   'n_epochs': 20,
#   'lstm_layers': 1,
#   'input_chunk_length': 172,
#   'hidden_size': 24,
#   'dropout': 0.2,
#   'batch_size': 32,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 6,
#   'n_epochs': 10,
#   'lstm_layers': 4,
#   'input_chunk_length': 48,
#   'hidden_size': 8,
#   'dropout': 0.3,
#   'batch_size': 64,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 2,
#   'n_epochs': 20,
#   'lstm_layers': 1,
#   'input_chunk_length': 48,
#   'hidden_size': 16,
#   'dropout': 0.2,
#   'batch_size': 32,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}},
#  {'output_chunk_length': 24,
#   'num_attention_heads': 2,
#   'n_epochs': 20,
#   'lstm_layers': 4,
#   'input_chunk_length': 48,
#   'hidden_size': 8,
#   'dropout': 0.1,
#   'batch_size': 128,
#   'use_static_covariates': True,
#   'add_encoders': {'cyclic': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'datetime_attribute': {'future': ['hour',
#      'day',
#      'dayofweek',
#      'week',
#      'month']},
#    'position': {'past': ['relative'], 'future': ['relative']},
#    'custom': {'past': [<function __main__.encode_year(idx)>],
#     'future': [<function __main__.encode_year(idx)>]},
#    'transformer': Scaler,
#    'tz': 'CET'},
#   'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}}]

# %%
# Initialize a list to store the results
rmse = []

# Define the loop function
for params in param_list:
  model = TFTModel(**params)

  # Cross validation with Rolling Forecasting Window
  cv = model.historical_forecasts(series = y_transformed,
                                  past_covariates = past_covariates_transformed,
                                  future_covariates = future_covariates_transformed,
                                  start = int((len(df)/2) - (10*forecast_horizon)), # Cast start to an integer
                                  forecast_horizon = forecast_horizon,
                                  stride = forecast_horizon, # / 2
                                  retrain = True,
                                  last_points_only = False)

  rmse_cv = []

  # Loop through each backtesting period
  for j in range(number_backtests):
    period_predictions = []

    # Collect the predictions
    for i in range(number_series):
      period_predictions.append(cv[i][j])

    # Unscale the preditions
    period_predictions_unscaled = scaler1.inverse_transform(period_predictions)

    # Calculate the RMSE for the current period for each series
    series_rmse = []
    for i in range(number_series):
      predictions = period_predictions_unscaled[i]
      predictions_df = predictions.to_dataframe()

      # Get the index for the predictions
      start = predictions_df.index.min()
      end = predictions_df.index.max()

      # Extract actual values for the time range and specific series
      actuals = df[(df['ds'] >= start) & (df['ds'] <= end) & (df['unique_id'] == i)]
      actuals = actuals.set_index('ds')['y']

      # Ensure that the index predictions match
      # print(predictions_df.index == actuals.index)

      # Calculate the RMSE
      error_cv = np.sqrt(mean_squared_error(actuals, predictions_df['y']))
      series_rmse.append(error_cv)

    # Append the mean RMSE for the current period
    rmse_cv.append(np.mean(series_rmse))

  # Calculate and print the mean RMSE for the current parameters and append it to the list of RMSE values
  mean_rmse = np.mean(rmse_cv)
  rmse.append(mean_rmse)
  print(f"Tested_params {params} = > RMSE: {mean_rmse}")
# Out:
# WARNING:darts.utils.historical_forecasts.utils:`enable_optimization=True` is ignored because `retrain` is not `False` or `0`. To hide this warning, set `show_warnings=False` or `enable_optimization=False`.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 1.1 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 576    | train
# 18 | output_layer                      | Linear                           | 289    | train
# ------------------------------------------------------------------------------------------------
# 58.1 K    Trainable params
# 0         Non-trainable params
# 58.1 K    Total params
# 0.232     Total estimated model params size (MB)
# 788       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 528    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 17.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 13.7 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 1.1 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 1.1 K  | train
# 10 | lstm_encoder                      | LSTM                             | 8.7 K  | train
# 11 | lstm_decoder                      | LSTM                             | 8.7 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 576    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 1.4 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 474    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 576    | train
# ...
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 320    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 9.9 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 7.9 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 304    | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 304    | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 304    | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 304    | train
# 10 | lstm_encoder                      | LSTM                             | 2.3 K  | train
# 11 | lstm_decoder                      | LSTM                             | 2.3 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 160    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 368    | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 212    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 160    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 304    | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 160    | train
# 18 | output_layer                      | Linear                           | 153    | train
# ------------------------------------------------------------------------------------------------
# 25.1 K    Trainable params
# 0         Non-trainable params
# 25.1 K    Total params
# 0.101     Total estimated model params size (MB)
# 604       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 320    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 9.9 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 7.9 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 304    | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 304    | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 304    | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 304    | train
# 10 | lstm_encoder                      | LSTM                             | 2.3 K  | train
# 11 | lstm_decoder                      | LSTM                             | 2.3 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 160    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 368    | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 212    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 160    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 304    | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 160    | train
# 18 | output_layer                      | Linear                           | 153    | train
# ------------------------------------------------------------------------------------------------
# 25.1 K    Trainable params
# 0         Non-trainable params
# 25.1 K    Total params
# 0.101     Total estimated model params size (MB)
# 604       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 320    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 9.9 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 7.9 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 304    | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 304    | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 304    | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 304    | train
# 10 | lstm_encoder                      | LSTM                             | 2.3 K  | train
# 11 | lstm_decoder                      | LSTM                             | 2.3 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 160    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 368    | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 212    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 160    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 304    | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 160    | train
# 18 | output_layer                      | Linear                           | 153    | train
# ------------------------------------------------------------------------------------------------
# 25.1 K    Trainable params
# 0         Non-trainable params
# 25.1 K    Total params
# 0.101     Total estimated model params size (MB)
# 604       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 320    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 9.9 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 7.9 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 304    | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 304    | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 304    | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 304    | train
# 10 | lstm_encoder                      | LSTM                             | 2.3 K  | train
# 11 | lstm_decoder                      | LSTM                             | 2.3 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 160    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 368    | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 212    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 160    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 304    | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 160    | train
# 18 | output_layer                      | Linear                           | 153    | train
# ------------------------------------------------------------------------------------------------
# 25.1 K    Trainable params
# 0         Non-trainable params
# 25.1 K    Total params
# 0.101     Total estimated model params size (MB)
# 604       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 320    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 9.9 K  | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 7.9 K  | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 304    | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 304    | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 304    | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 304    | train
# 10 | lstm_encoder                      | LSTM                             | 2.3 K  | train
# 11 | lstm_decoder                      | LSTM                             | 2.3 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 160    | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 368    | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 212    | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 160    | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 304    | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 160    | train
# 18 | output_layer                      | Linear                           | 153    | train
# ------------------------------------------------------------------------------------------------
# 25.1 K    Trainable params
# 0         Non-trainable params
# 25.1 K    Total params
# 0.101     Total estimated model params size (MB)
# 604       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Tested_params {'output_chunk_length': 24, 'num_attention_heads': 2, 'n_epochs': 20, 'lstm_layers': 4, 'input_chunk_length': 48, 'hidden_size': 8, 'dropout': 0.1, 'batch_size': 128, 'use_static_covariates': True, 'add_encoders': {'cyclic': {'future': ['hour', 'day', 'dayofweek', 'week', 'month']}, 'datetime_attribute': {'future': ['hour', 'day', 'dayofweek', 'week', 'month']}, 'position': {'past': ['relative'], 'future': ['relative']}, 'custom': {'past': [<function encode_year at 0x7c1e2568da80>], 'future': [<function encode_year at 0x7c1e2568da80>]}, 'transformer': Scaler, 'tz': 'CET'}, 'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}} = > RMSE: 36.00057915390193

# %%
# Create a DataFrame and add the RMSE values
results_df = pd.DataFrame(param_list2)
results_df['rmse'] = rmse
results_df
# Out:
#    output_chunk_length  num_attention_heads  n_epochs  lstm_layers  \
# 0                   24                    6        10            4
# 1                   24                    4        20            4
# 2                   24                    6        10            4
# 3                   24                    2        20            2
# 4                   24                    2         5            4
# 5                   24                    2         5            2
# 6                   24                    4        20            1
# 7                   24                    6        10            4
# 8                   24                    2        20            1
# 9                   24                    2        20            4
#
#    input_chunk_length  hidden_size  dropout  batch_size  \
# 0                  96           16      0.1          64
# 1                 172            8      0.3          64
# 2                 172           16      0.2          64
# 3                  96           16      0.2          64
# 4                  48           24      0.1         128
# 5                 172           24      0.3         128
# 6                 172           24      0.2          32
# 7                  48            8      0.3          64
# 8                  48           16      0.2          32
# 9                  48            8      0.1         128
#
#    use_static_covariates                                       add_encoders  \
# 0                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 1                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 2                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 3                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 4                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 5                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 6                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 7                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 8                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
# 9                   True  {'cyclic': {'future': ['hour', 'day', 'dayofwe...
#
#                         pl_trainer_kwargs        rmse
# 0  {'accelerator': 'gpu', 'devices': [0]}   37.432474
# 1  {'accelerator': 'gpu', 'devices': [0]}   29.835429
# 2  {'accelerator': 'gpu', 'devices': [0]}   34.770594
# 3  {'accelerator': 'gpu', 'devices': [0]}   24.309072
# 4  {'accelerator': 'gpu', 'devices': [0]}   80.547875
# 5  {'accelerator': 'gpu', 'devices': [0]}  101.479759
# 6  {'accelerator': 'gpu', 'devices': [0]}   16.898447
# 7  {'accelerator': 'gpu', 'devices': [0]}   49.363726
# 8  {'accelerator': 'gpu', 'devices': [0]}   17.066883
# 9  {'accelerator': 'gpu', 'devices': [0]}   36.000579

# %%
# Identify the parameter set(s) with the lowest RMSE and export it to a CSV file
best_params = results_df[results_df['rmse'] == results_df['rmse'].min()]
best_params.to_csv('best_params.csv')

# %% [markdown]
# ## Visualize the predictions

# %%
for i in range(len(cv)):
  plt.figure(figsize=(15, 6))
  # Convert to pandas DataFrame before plotting and plot a subset
  predictions_df = scaler1.inverse_transform(cv[i]).to_dataframe()
  predictions_df.plot(label = 'Predictions',ax=plt.gca())

  # Convert to pandas DataFrame before plotting and plot a subset
  series_df = series.to_dataframe()
  series_df.plot(label = 'Actuals', ax=plt.gca())

  plt.title(f"M4 Fitting: validation for fold {i}")
  plt.legend()
  plt.show()

# %% [markdown]
# ## Predict the Future

# %%
# Load the best parameters from the CSV file, and put it in a dictionary
best_params = pd.read_csv('best_params.csv', index_col =0).drop(columns = "rmse")
best_params_dict = best_params.squeeze().to_dict()
best_params_dict
# Out:
# {'output_chunk_length': 24,
#  'num_attention_heads': 4,
#  'n_epochs': 20,
#  'lstm_layers': 1,
#  'input_chunk_length': 172,
#  'hidden_size': 24,
#  'dropout': 0.2,
#  'batch_size': 32,
#  'use_static_covariates': True,
#  'add_encoders': "{'cyclic': {'future': ['hour', 'day', 'dayofweek', 'week', 'month']}, 'datetime_attribute': {'future': ['hour', 'day', 'dayofweek', 'week', 'month']}, 'position': {'past': ['relative'], 'future': ['relative']}, 'custom': {'past': [<function encode_year at 0x7c1e2568da80>], 'future': [<function encode_year at 0x7c1e2568da80>]}, 'transformer': Scaler, 'tz': 'CET'}",
#  'pl_trainer_kwargs': "{'accelerator': 'gpu', 'devices': [0]}"}

# %%
# List of parameters that should be converted to integers
int_params = ['input_chunk_length', 'output_chunk_length',
              'hidden_size', 'num_attention_heads', 'batch_size',
              'lstm_layers', 'n_epochs']

# Convert specified float parameters to integers
for key in int_params:
  best_params_dict[key] = int(best_params_dict[key])

# %%
# Update the best parameters dictionary with the fixed parameters
best_params_dict.update(fixed_params)
best_params_dict
# Out:
# {'output_chunk_length': 24,
#  'num_attention_heads': 4,
#  'n_epochs': 20,
#  'lstm_layers': 1,
#  'input_chunk_length': 172,
#  'hidden_size': 24,
#  'dropout': 0.2,
#  'batch_size': 32,
#  'use_static_covariates': True,
#  'add_encoders': {'cyclic': {'future': ['hour',
#     'day',
#     'dayofweek',
#     'week',
#     'month']},
#   'datetime_attribute': {'future': ['hour',
#     'day',
#     'dayofweek',
#     'week',
#     'month']},
#   'position': {'past': ['relative'], 'future': ['relative']},
#   'custom': {'past': [<function __main__.encode_year(idx)>],
#    'future': [<function __main__.encode_year(idx)>]},
#   'transformer': Scaler,
#   'tz': 'CET'},
#  'pl_trainer_kwargs': {'accelerator': 'gpu', 'devices': [0]}}

# %%
# Build the TFT model using the best-tuned parameters
tuned_tft = TFTModel(**best_params_dict)

# Fit the tuned model
tuned_tft.fit(y_transformed,
                past_covariates = past_covariates_transformed,
                future_covariates = future_covariates_transformed)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name                              | Type                             | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | train_metrics                     | MetricCollection                 | 0      | train
# 1  | val_metrics                       | MetricCollection                 | 0      | train
# 2  | input_embeddings                  | _MultiEmbedding                  | 0      | train
# 3  | static_covariates_vsn             | _VariableSelectionNetwork        | 712    | train
# 4  | encoder_vsn                       | _VariableSelectionNetwork        | 24.2 K | train
# 5  | decoder_vsn                       | _VariableSelectionNetwork        | 18.1 K | train
# 6  | static_context_grn                | _GatedResidualNetwork            | 2.4 K  | train
# 7  | static_context_hidden_encoder_grn | _GatedResidualNetwork            | 2.4 K  | train
# 8  | static_context_cell_encoder_grn   | _GatedResidualNetwork            | 2.4 K  | train
# 9  | static_context_enrichment         | _GatedResidualNetwork            | 2.4 K  | train
# 10 | lstm_encoder                      | LSTM                             | 4.8 K  | train
# 11 | lstm_decoder                      | LSTM                             | 4.8 K  | train
# 12 | post_lstm_gan                     | _GateAddNorm                     | 1.2 K  | train
# 13 | static_enrichment_grn             | _GatedResidualNetwork            | 3.0 K  | train
# 14 | multihead_attn                    | _InterpretableMultiHeadAttention | 1.5 K  | train
# 15 | post_attn_gan                     | _GateAddNorm                     | 1.2 K  | train
# 16 | feed_forward_block                | _GatedResidualNetwork            | 2.4 K  | train
# 17 | pre_output_gan                    | _GateAddNorm                     | 1.2 K  | train
# 18 | output_layer                      | Linear                           | 425    | train
# ------------------------------------------------------------------------------------------------
# 73.3 K    Trainable params
# 0         Non-trainable params
# 73.3 K    Total params
# 0.293     Total estimated model params size (MB)
# 784       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# TFTModel(output_chunk_shift=0, hidden_size=24, lstm_layers=1, num_attention_heads=4, full_attention=False, feed_forward=GatedResidualNetwork, dropout=0.2, hidden_continuous_size=8, categorical_embedding_sizes=None, add_relative_index=False, loss_fn=None, likelihood=None, norm_type=LayerNorm, use_static_covariates=True, output_chunk_length=24, n_epochs=20, input_chunk_length=172, batch_size=32, add_encoders={'cyclic': {'future': ['hour', 'day', 'dayofweek', 'week', 'month']}, 'datetime_attribute': {'future': ['hour', 'day', 'dayofweek', 'week', 'month']}, 'position': {'past': ['relative'], 'future': ['relative']}, 'custom': {'past': [<function encode_year at 0x7c1e2568da80>], 'future': [<function encode_year at 0x7c1e2568da80>]}, 'transformer': Scaler, 'tz': 'CET'}, pl_trainer_kwargs={'accelerator': 'gpu', 'devices': [0]})

# %%
# Generate forecasts for the future using the tuned model
predictions = tuned_tft.predict(n=forecast_horizon,
                         series = y_transformed,
                         past_covariates = past_covariates_transformed,
                         future_covariates = future_covariates_transformed)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
# Unscale the predictions using the inverse transform
unscaled_predictions = scaler1.inverse_transform(predictions)

# Convert each time series in the unscaled predictions to a DataFrame
dataframes = [ts.to_dataframe() for ts in unscaled_predictions]

# Optionally concatenate all DataFrames into a single DataFrame
forecasts_dataframe = pd.concat(dataframes, axis = 0)

# Export the concatenated forecasts DataFrame to a CSV file
forecasts_dataframe.to_csv("forecasts_multi_tft.csv")
